# %% [markdown]
# # Career Prediction Preprocessing and Data Understanding

# %%
import pandas as pd
import numpy as np
# Out:
# d:\year 3 materials\year 4\graduation project\PathFinder\data understanding

# %%
from pathlib import Path
import pandas as pd

DATA_PATH = Path("../data/career_dataset.csv")
data = pd.read_csv(DATA_PATH)
data.head()
# Out:
#    Unnamed: 0  Acedamic percentage in Operating Systems  \
# 0           0                                        69
# 1           1                                        78
# 2           2                                        71
# 3           3                                        76
# 4           4                                        92
#
#    percentage in Algorithms  Percentage in Programming Concepts  \
# 0                        63                                  78
# 1                        62                                  73
# 2                        86                                  91
# 3                        87                                  60
# 4                        62                                  90
#
#    Percentage in Software Engineering  Percentage in Computer Networks  \
# 0                                  87                               94
# 1                                  60                               71
# ...

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 39 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Unnamed: 0                                20000 non-null  int64
#  1   Acedamic percentage in Operating Systems  20000 non-null  int64
#  2   percentage in Algorithms                  20000 non-null  int64
#  3   Percentage in Programming Concepts        20000 non-null  int64
#  4   Percentage in Software Engineering        20000 non-null  int64
#  5   Percentage in Computer Networks           20000 non-null  int64
#  6   Percentage in Electronics Subjects        20000 non-null  int64
#  7   Percentage in Computer Architecture       20000 non-null  int64
#  8   Percentage in Mathematics                 20000 non-null  int64
#  9   Percentage in Communication skills        20000 non-null  int64
# ...

# %% [markdown]
# removed index column

# %%
data = data.drop(columns=['Unnamed: 0'])
